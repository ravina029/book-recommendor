# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books_df=pd.read_csv('Books.csv')
# Out:
# /var/folders/3t/5qtlv2451k3fkqv9ls22lmg00000gn/T/ipykernel_35357/2330454682.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books_df=pd.read_csv('Books.csv')

# %%
books_df.head(5)
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books_df.shape
# Out:
# (271360, 8)

# %%
books_df.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
books_df.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
df_books=books_df[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher', 'Image-URL-L']]

# %%
df_books.rename(columns={'Book-Title':'Book',
                         'Book-Author':"Author",
                         'Year-Of-Publication':"year",
                         'Image-URL-L':"url"
                         },inplace=True)
# Out:
# /var/folders/3t/5qtlv2451k3fkqv9ls22lmg00000gn/T/ipykernel_35357/1663060314.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_books.rename(columns={'Book-Title':'Book',

# %%
df_books.head()
# Out:
#          ISBN                                               Book  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  Author  year                   Publisher  \
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
#
#                                                  url
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# ...

# %%
#User's Datasets
users=pd.read_csv('Users.csv')
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users.shape
# Out:
# (278858, 3)

# %%
ratings=pd.read_csv('Ratings.csv')

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
ratings.rename(columns={"User-ID":"user_id",
                        "Book-Rating":"rating"},inplace=True)

# %%
ratings.head()
# Out:
#    user_id        ISBN  rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6

# %%
ratings['user_id'].value_counts()
# Out:
# user_id
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: count, Length: 105283, dtype: int64

# %%
ratings['user_id'].unique().shape
# Out:
# (105283,)

# %%
a=ratings['user_id'].value_counts()>100

# %%
a[a].shape
# Out:
# (1825,)

# %%
b=a[a].index

# %%
ratings=ratings[ratings['user_id'].isin(b)]

# %%
ratings.shape
# Out:
# (656605, 3)

# %%
books_with_ratings=ratings.merge(df_books, on='ISBN')

# %%
books_with_ratings.head()
# Out:
#    user_id        ISBN  rating  \
# 0   276925  002542730X      10
# 1   277427  002542730X      10
# 2     3363  002542730X       0
# 3    10030  002542730X       7
# 4    11676  002542730X       6
#
#                                                 Book             Author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    Publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
# 3  John Wiley &amp; Sons Inc
# 4  John Wiley &amp; Sons Inc
#
#                                                  url
# 0  http://images.amazon.com/images/P/002542730X.0...
# ...

# %%
rating_counts=books_with_ratings.groupby('Book')['rating'].count().reset_index()

# %%
rating_counts.head()
# Out:
#                                                 Book  rating
# 0   A Light in the Storm: The Civil War Diary of ...       3
# 1                              Always Have Popsicles       1
# 2               Apple Magic (The Collector's series)       1
# 3   Beyond IBM: Leadership Marketing and Finance ...       1
# 4   Clifford Visita El Hospital (Clifford El Gran...       1

# %%
final_ratings=books_with_ratings.merge(rating_counts, on='Book')

# %%
final_ratings.head()
# Out:
#    user_id        ISBN  rating_x  \
# 0   276925  002542730X        10
# 1   277427  002542730X        10
# 2     3363  002542730X         0
# 3    10030  002542730X         7
# 4    11676  002542730X         6
#
#                                                 Book             Author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    Publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
# 3  John Wiley &amp; Sons Inc
# 4  John Wiley &amp; Sons Inc
#
#                                                  url  rating_y
# ...

# %%
final_ratings.shape
# Out:
# (604854, 9)

# %%
final_rating=final_ratings[final_ratings['rating_y']>70]

# %%
final_rating.shape
# Out:
# (71435, 9)

# %%
final_rating.sample(20)
# Out:
#         user_id        ISBN  rating_x  \
# 19218    181076  1400034779         0
# 48344    224138  042511774X         0
# 90328    240144  059035342X        10
# 202563   185384  0671867156         0
# 59973     78973  055356451X         7
# 154244   232945  0446603929         0
# 21763    157273  0449907481         0
# 387       95932  0316666343         0
# 135622    11676  0374172897         0
# 106013    69405  0060928336         0
# 54098     64436  0446672211         0
# 159194   259260  0804117683         0
# 86686     35050  034540288X         0
# 3669      93363  0142001740         0
# 26667    234623  0446612790         0
# 177853   170184  0440224624         0
# 44153    110973  0380018179         0
# 70905    162590  014028009X         9
# 140358   201526  0385471440         0
# 52840    136205  044651652X         0
#
#                                                      Book  \
# 19218   The No. 1 Ladies' Detective Agency (Today Show...
# ...

# %%
print(final_rating.duplicated('user_id').sum())
print(final_rating.duplicated('Book').sum())
# Out:
# 69659
# 70836

# %%
final_rating.drop_duplicates(['user_id','Book'],inplace=True)
# Out:
# /var/folders/3t/5qtlv2451k3fkqv9ls22lmg00000gn/T/ipykernel_35357/3223901068.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_rating.drop_duplicates(['user_id','Book'],inplace=True)

# %%
final_rating.shape
# Out:
# (69541, 9)

# %%
final_rating.head()
# Out:
#    user_id        ISBN  rating_x  \
# 0   276925  002542730X        10
# 1   277427  002542730X        10
# 2     3363  002542730X         0
# 3    10030  002542730X         7
# 4    11676  002542730X         6
#
#                                                 Book             Author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    Publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
# 3  John Wiley &amp; Sons Inc
# 4  John Wiley &amp; Sons Inc
#
#                                                  url  rating_y
# ...

# %%
book_pivot=final_rating.pivot_table(columns='user_id',index='Book',values='rating_x')

# %%
book_pivot
# Out:
# user_id                                             183     254     507     \
# Book
# 1984                                                   NaN     9.0     NaN
# 1st to Die: A Novel                                    NaN     NaN     0.0
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     0.0     NaN
# ...                                                    ...     ...     ...
# Wizard and Glass (The Dark Tower, Book 4)              NaN     NaN     NaN
# Wuthering Heights                                      NaN     NaN     NaN
# Year of Wonders                                        NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
book_pivot.shape
# Out:
# (599, 1776)

# %%
book_pivot.fillna(0, inplace=True)

# %%
book_pivot
# Out:
# user_id                                             183     254     507     \
# Book
# 1984                                                   0.0     9.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Wizard and Glass (The Dark Tower, Book 4)              0.0     0.0     0.0
# Wuthering Heights                                      0.0     0.0     0.0
# Year of Wonders                                        0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
! pip install scipy

# %%
#we don't want to consider 0 values
from scipy.sparse import csr_matrix

# %%
book_non_sparse=csr_matrix(book_pivot)

# %%
book_non_sparse
# Out:
# <599x1776 sparse matrix of type '<class 'numpy.float64'>'
# 	with 19617 stored elements in Compressed Sparse Row format>

# %%
! pip install scikit-learn

# %%
from sklearn.neighbors import NearestNeighbors
model=NearestNeighbors(algorithm='brute')

# %%
model.fit(book_non_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distance,suggestion=model.kneighbors(book_pivot.iloc[260,:].values.reshape(1,-1),n_neighbors=7)

# %%
distance
# Out:
# array([[ 0.        , 39.44616585, 40.18706259, 41.0487515 , 41.14608122,
#         41.34005322, 42.28474902]])

# %%
suggestion
# Out:
# array([[260, 387, 290, 501, 552, 322, 154]])

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['Mercy', 'Temptation', 'Night Whispers', 'The Reef',
#        'Tom Clancy's Op-Center (Tom Clancy's Op Center (Paperback))',
#        'Purity in Death', 'Fat Tuesday'],
#       dtype='object', name='Book')

# %%
books_name=book_pivot.index

# %%
import pickle
pickle.dump(model,open('artifacts/model.pkl','wb'))
pickle.dump(books_name,open('artifacts/book_name.pkl','wb'))
pickle.dump(final_rating,open('artifacts/final_rating.pkl','wb'))
pickle.dump(book_pivot,open('artifacts/book_pivot.pkl','wb'))

# %%
def recommend(book):
    book_id=np.where(book_pivot.index==book)[0][0]
    distance,suggestion=model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1),n_neighbors=7)

    for i in range(len(suggestion)):
        books=book_pivot.index[suggestion[i]]

        for j in books:
            print(j)

# %%
book_name='Harry Potter and the Chamber of Secrets (Book 2)'
recommend(book_name)
# Out:
# Harry Potter and the Chamber of Secrets (Book 2)
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Sorcerer's Stone (Book 1)
# Tom Clancy's Op-Center (Tom Clancy's Op Center (Paperback))
# Bittersweet
# The Long Road Home
